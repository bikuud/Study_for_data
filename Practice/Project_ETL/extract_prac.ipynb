# %%
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests

#1 타겟 URL 설정
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"
}
url= 'https://gall.dcinside.com/mgallery/board/lists?id=pokemontcgpocket'
response=requests.get(url, headers=headers)
if response.status_code==200:
    print('서버는 잘 작동함, 이제 크롤링 해보겠음')
    soup=BeautifulSoup(response.text, 'html.parser')
    rows=soup.select('tr.ub-content.us-post')
    print(f'찾은 게시글 갯수 {len(rows)}')
    for row in rows:
        # 1. 제목이 있는 a 태그를 찾습니다.
        title_element = row.select_one('td.gall_tit.ub-word > a')
        if title_element:
            # 2. a 태그 안의 'em' 태그(아이콘)를 제거합니다.
            for em in title_element.select('em'):
                em.decompose() # .decompose()는 태그 자체를 완전히 삭제합니다.
            # 3. 이제 깨끗해진 텍스트만 추출합니다.
            title_text = title_element.text.strip()
            print(f"제목: {title_text}")
        else:
            print('뭐가 문제니 대체?')

else:
    print('일단 서버부터 응답 안함 ^^')
# Out:
# 서버는 잘 작동함, 이제 크롤링 해보겠음
# 찾은 게시글 갯수 50
# 제목: 신문고
# 제목: 포켓몬 카드 게임 포켓 갤러리 이용규칙 (260630)
# 제목: ※ 트레이드탭은 고닉/반고닉만 이용 가능 ※
# 제목: 포켓 갤러리 공지및 정보글 모음
# 제목: 포켓몬 카드 게임 포켓 뉴비가이드 & 리세가이드
# 제목: 포켓몬 카드 게임 포켓 일반 공략 정리글
# 제목: 24시간 겟챌 총정리본
# 제목: 3333 따봉
# 제목: 모르는 사람이
# 제목: 첫판부터 상대 아이스 6연 앞면
# 제목: 2다 밤선인 구해봅니다
# 제목: 1별 피카츄로 1별 식스테일 구합니다
# 제목: 모래성 같은 좆병신덱이 top 8이나 올라가다니
# 제목: 다음 팩 5세대 확정이니까 너무 기대된다 ㅎㅎ
# 제목: 1별 잠만보로 식스테일 구합니다노
# 제목: 뉴비질문
# 제목: 랑딸랑 한 장 구해용!!!
# 제목: 이번 신팩 포켓몬 2성 중에서는
# 제목: 뉴비 크몬볼 리세 드디어 성공함
# 제목: 10포남았드아
# 제목: 신팩 4다이아 구해요!
# 제목: 4다 밀로틱 메가디안시 나눠주기 구함
# 제목: 104명 대회 우승 메무킹개닌
# 제목: 레전드갓팩떴다
# 제목: 상대방 다음턴에 서포트카드 사용못하게 하는 여캐 서포트카드가 나오면
# 제목: 님피아 1성과 2다 3다 몇개 구합니다
# 제목: 박연 받아갔음
# 제목: 페로코체 한장 구해요
# 제목: 아니 이거 언제고침? 볼때마다 불편하네
# 제목: 메가가디안 ex 4다 구해요
# 제목: 박연 받아가셈
# 제목: 3다 다투곰 트레로 구함
# 제목: 신팩 정가권 맞밸이 어느정도임?
# 제목: 뉴비는 말라죽으란말이냐!
# 제목: 엠블럼 케이크처럼 쉽게 따먹는 덱
# 제목: 미라자포 어케 운영함
# 제목: 똥퍼컵 12번마 마티스 덱리 제출함
# 제목: 역상성 컷
# 제목: 이로치 리피아EX 구합니다
# 제목: 24겟챌 혹시 도감 채웠다가 트레해서 0장 된것도 다시 채워야지 뜸?
# 제목: 쌀먹러들아 24시갯첼 1성도 모래써서 클리어함??
# 제목: 나눠주기로 아가방 하나 구해봅니다
# 제목: 부계 팩 100개 깟는데 크라운 2개면 본계 버림?
# 제목: 이번팩 유독 제자리겟챌이 많음
# 제목: 무댠시 결과
# 제목: 겨드랑이 쯉쯉
# 제목: 24겟 무댠시
# 제목: 제초완료
# 제목: 메가디안시 나눠주기로 메가깜까미ex 구함
# 제목: 엠블퀘 시작부터 4연패 박아서 1승하고 껐다...
