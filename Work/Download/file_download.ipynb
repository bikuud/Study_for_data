# %%
# 페이지 띄우기 및 팝업 제거
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time
from bs4 import BeautifulSoup
options=Options()
base_url='https://nkinfo.unikorea.go.kr/nkp/report/list.do?pstgSeCode=ARGUMENT_WIK&menuId=ARGUMENT_82'
options.add_argument("--window-size=1920, 1080")
driver=webdriver.Chrome(options=options)
try:
    driver.get(base_url)
    time.sleep(2)
    html=driver.page_source
    soup=BeautifulSoup(html, 'html.parser')
    post_num=soup.find_all('td', class_='hide_768')
    for num in post_num:
        print(num.get_text().strip()) ## 글 번호 따오기
        

except:
    print('뭔가 잘못했어 임마')
# Out:
# 1479
#
# 1478
#
# 1477
#
# 1476
#
# 1475
#
# 1474
#
# 1473
#
# 1472
#
# 1471
#
# 1470

# %%
post_num
# Out:
# [<td class="hide_768">1479</td>,
#  <td class="icon_inside hide_768">
#  <div class="td_wrap colGap_5px">
#  <a class="icon icon_hwpx attachFile" data-file-no="1" data-trend-report-no="10800" href="javascript:void(0);"></a>
#  <a class="icon icon_pdf attachFile" data-file-no="2" data-trend-report-no="10800" href="javascript:void(0);"></a>
#  </div>
#  </td>,
#  <td class="hide_768">1478</td>,
#  <td class="icon_inside hide_768">
#  <div class="td_wrap colGap_5px">
#  <a class="icon icon_hwpx attachFile" data-file-no="3" data-trend-report-no="10795" href="javascript:void(0);"></a>
#  <a class="icon icon_pdf attachFile" data-file-no="4" data-trend-report-no="10795" href="javascript:void(0);"></a>
#  </div>
#  </td>,
#  <td class="hide_768">1477</td>,
#  <td class="icon_inside hide_768">
#  <div class="td_wrap colGap_5px">
#  <a class="icon icon_hwpx attachFile" data-file-no="1" data-trend-report-no="10790" href="javascript:void(0);"></a>
#  <a class="icon icon_pdf attachFile" data-file-no="2" data-trend-report-no="10790" href="javascript:void(0);"></a>
#  </div>
#  </td>,
#  <td class="hide_768">1476</td>,
#  <td class="icon_inside hide_768">
#  <div class="td_wrap colGap_5px">
#  <a class="icon icon_hwpx attachFile" data-file-no="1" data-trend-report-no="10785" href="javascript:void(0);"></a>
#  <a class="icon icon_pdf attachFile" data-file-no="2" data-trend-report-no="10785" href="javascript:void(0);"></a>
#  </div>
#  </td>,
#  <td class="hide_768">1475</td>,
#  <td class="icon_inside hide_768">
#  <div class="td_wrap colGap_5px">
#  <a class="icon icon_hwpx attachFile" data-file-no="1" data-trend-report-no="10781" href="javascript:void(0);"></a>
#  <a class="icon icon_pdf attachFile" data-file-no="2" data-trend-report-no="10781" href="javascript:void(0);"></a>
#  </div>
#  </td>,
#  <td class="hide_768">1474</td>,
#  <td class="icon_inside hide_768">
#  <div class="td_wrap colGap_5px">
#  <a class="icon icon_hwpx attachFile" data-file-no="1" data-trend-report-no="10774" href="javascript:void(0);"></a>
#  <a class="icon icon_pdf attachFile" data-file-no="2" data-trend-report-no="10774" href="javascript:void(0);"></a>
#  </div>
#  </td>,
#  <td class="hide_768">1473</td>,
#  <td class="icon_inside hide_768">
#  <div class="td_wrap colGap_5px">
#  <a class="icon icon_hwpx attachFile" data-file-no="1" data-trend-report-no="10771" href="javascript:void(0);"></a>
#  <a class="icon icon_pdf attachFile" data-file-no="2" data-trend-report-no="10771" href="javascript:void(0);"></a>
#  </div>
#  </td>,
#  <td class="hide_768">1472</td>,
#  <td class="icon_inside hide_768">
#  <div class="td_wrap colGap_5px">
#  <a class="icon icon_hwpx attachFile" data-file-no="3" data-trend-report-no="10765" href="javascript:void(0);"></a>
#  <a class="icon icon_pdf attachFile" data-file-no="4" data-trend-report-no="10765" href="javascript:void(0);"></a>
#  </div>
#  </td>,
#  <td class="hide_768">1471</td>,
#  <td class="icon_inside hide_768">
#  <div class="td_wrap colGap_5px">
#  <a class="icon icon_hwpx attachFile" data-file-no="1" data-trend-report-no="10760" href="javascript:void(0);"></a>
#  <a class="icon icon_pdf attachFile" data-file-no="2" data-trend-report-no="10760" href="javascript:void(0);"></a>
#  </div>
#  </td>,
#  <td class="hide_768">1470</td>,
#  <td class="icon_inside hide_768">
#  <div class="td_wrap colGap_5px">
#  <a class="icon icon_hwpx attachFile" data-file-no="3" data-trend-report-no="10754" href="javascript:void(0);"></a>
#  <a class="icon icon_pdf attachFile" data-file-no="4" data-trend-report-no="10754" href="javascript:void(0);"></a>
#  </div>
#  </td>]
